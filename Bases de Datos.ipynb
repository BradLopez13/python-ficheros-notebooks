# %% [markdown]
# # BASES DE DATOS

# %%
import sqlite3

# %%
conexion = sqlite3.connect('ejemplo.db')

# %%
conexion.close()

# %% [markdown]
# ## CREAR TABLA

# %%
conexion = sqlite3.connect('ejemplo.db')

# %%
cursor = conexion.cursor()

# %%
cursor.execute('create table alumnos (nombre varchar(50), edad integer, email varchar(100))')

# %%
conexion.commit()

# %%
conexion.close()

# %% [markdown]
# ## INSERTAR UNO Y VARIOS

# %%
conexion = sqlite3.connect('ejemplo.db')
cursor = conexion.cursor()
cursor.execute('insert into alumnos values ("Angel",20,"angel@example.com")')
conexion.commit()
conexion.close()

# %%
conexion = sqlite3.connect('ejemplo.db')
cursor = conexion.cursor()
alum = [('Isaac',10,'isaac@example.com'),('Juan',30,'juan@example.com'),('Angela',19,'angela@example.com')]
cursor.executemany("insert into alumnos values (?,?,?)",alum)
conexion.commit()
conexion.close()

# %% [markdown]
# ## LECTURA

# %%
conexion = sqlite3.connect('ejemplo.db')
cursor = conexion.cursor()
cursor.execute('select * from alumnos')
lalumnos = cursor.fetchall()
for alumnos in lalumnos:
    print(alumnos)
# Out:
# ('Fer', 22, 'fer@example.com')
# ('Angel', 20, 'angel@example.com')
# ('Isaac', 10, 'isaac@example.com')
# ('Juan', 30, 'juan@example.com')
# ('Angela', 19, 'angela@example.com')
